# %% [markdown]
# 1. customer_id is unique within customers.
# 2. customer_unique_id is not unique within customers.
# 3. order_id is unique within orders.
# 4. reviews require a composite key of order_id + review_id.
# 5. Several order delivery timestamps contain NULL values.
# 6. Review comments have substantial missingness.
# 7. Products contain missing category information.
# 8. Foreign-key relationships were investigated.
# 9. Payment installment anomalies were identified.
